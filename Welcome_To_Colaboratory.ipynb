# %% [markdown]
# <a href="https://colab.research.google.com/github/vinay4235/22MH1A4235/blob/main/Welcome_To_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
corpus=['data science is one of the most important felids of science','this is one of the best data science','data scientists analyze data']

# %%
words_set=set()
for doc in corpus:
  words=doc.split(' ')
  words_set=words_set.union(set(words))
print('number of words in the corpus:',len(words_set))
print('the words in the corpus:\n',words_set)
n_docs=len(corpus)
n_words_set=len(words_set)
words_list=list(words_set)
# Out:
# number of words in the corpus: 13
# the words in the corpus:
#  {'data', 'scientists', 'one', 'most', 'important', 'science', 'felids', 'analyze', 'this', 'is', 'best', 'the', 'of'}

# %%
df_tf=pd.DataFrame(np.zeros((n_docs,n_words_set)),columns=words_list)
for i in range(n_docs):
  words=corpus[i].split(' ')
  for w in words:
    df_tf[w][i]=df_tf[w][i]+(1/len(words))
df_tf
# Out:
#        data  scientists       one      most  important   science    felids  \
# 0  0.090909        0.00  0.090909  0.090909   0.090909  0.181818  0.090909
# 1  0.125000        0.00  0.125000  0.000000   0.000000  0.125000  0.000000
# 2  0.500000        0.25  0.000000  0.000000   0.000000  0.000000  0.000000
#
#    analyze   this        is   best       the        of
# 0     0.00  0.000  0.090909  0.000  0.090909  0.181818
# 1     0.00  0.125  0.125000  0.125  0.125000  0.125000
# 2     0.25  0.000  0.000000  0.000  0.000000  0.000000
